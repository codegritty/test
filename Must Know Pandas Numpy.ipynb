# %% [markdown]
# # **CREATE DATAFRAME OF COLUMNS AND DATA**

# %%
df = pd.DataFrame({
    'name' : ['george','malone','justin','wonderkid','cathy','jon'],
    'age'  : [23,43,35,12,36,40],
    'location': ['MD','NY','CA','TX','CA','FL'],
    'id'   : [1,2,3,4,5,6],
    'sex'  : ['male','male','male','female','female','male'],
    'itemid':[1,1,3,5,4,2],
    'salary':[3000,4000,1000,500,300000,0],
    'email': ['jo@gmail','meg@yahoo','john@gmail','sue@gmail','dice@yahoo','shoes@hotmail']
})

# %%
df2 = pd.DataFrame({
    'itemid'  : [1,2,3,4,5],
    'item': ['couch','table','chair','lamp','mirror']
})

# %% [markdown]
# # SET MAX COLUMNS

# %%
pd.set_option("display.max_columns",100)

# %% [markdown]
# # CREATE NEW COLUMN -9NR

# %%
# as if you were calling a new column
df['salary'] = [3000,4000,5000,6000,7000]

# %%
#create new column name with math
sales['current_price_times_quantity'] = sales['Current_Price'] * sales['Quantity']
sales

# %% [markdown]
# # **DISPLAY THE COLUMNS**

# %%
print(df.columns)
# Out:
# Index(['name', 'age', 'pet', 'score'], dtype='object')

# %% [markdown]
# # **DISPLAY INDEX**

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# # **SHOW WAYS TO DISPLAY DATA FROM 1 COLUMN**

# %%
df['age']
# Out:
# 0    20
# 1     0
# 2    40
# Name: age, dtype: int64

# %%
df.name
# Out:
# 0    Bob
# 1    Jen
# 2    Tim
# Name: name, dtype: object

# %%
df.age #same as putting in brackets
# Out:
# 0    20
# 1     0
# 2    40
# Name: age, dtype: int64

# %%
df['name']
# Out:
# 0    Bob
# 1    Jen
# 2    Tim
# Name: name, dtype: object

# %%
df.name
# Out:
# 0    Bob
# 1    Jen
# 2    Tim
# Name: name, dtype: object

# %% [markdown]
# # **SHOW DATA FOR MORE THAN ONE COLUMN**

# %%
df[['name','pet']]
# Out:
#   name   pet
# 0  Bob   cat
# 1  Jen   dog
# 2  Tim  bird

# %% [markdown]
# # **DISPLAY COLUMN NAMES USING INDEXING**

# %%
df.columns[0:3]
# Out:
# Index(['name', 'age', 'pet'], dtype='object')

# %%
df.columns[0:2]
# Out:
# Index(['name', 'age'], dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'age', 'pet', 'score'], dtype='object')

# %%
#NOT AS USED AS MUCH
df.ix[0]
# Out:
# C:\Users\rjjav\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# name     Bob
# age       20
# pet      cat
# score      0
# Name: 0, dtype: object

# %% [markdown]
# # **SORT COLUMN**

# %%
df.sort_values('pet', inplace=True)
df
# Out:
#    age name   pet  score
# 2   40  Tim  bird      4
# 0   20  Bob   cat      0
# 1    0  Jen   dog      3

# %%
df.sort_values(by='pet')
df
# Out:
#    age name   pet  score
# 2   40  Tim  bird      4
# 0   20  Bob   cat      0
# 1    0  Jen   dog      3

# %% [markdown]
# # DISPLAY DATA OF COLUMN using ROW/COLUMN LOCATION -UND3R

# %%
df.iloc[1,2]
# Out:
# 'cat'

# %%
df.iloc[2,0]
# Out:
# 'Jen'

# %%
#picks up entire row of [ ]
df.iloc[0]
# Out:
# name      Tim
# age        40
# pet      bird
# score       4
# Name: 2, dtype: object

# %%
df.iloc[2]
# Out:
# name     Jen
# age        0
# pet      dog
# score      3
# Name: 1, dtype: object

# %%
df.iloc[:,0:2]
# Out:
#   name  age
# 2  Tim   40
# 0  Bob   20
# 1  Jen    0

# %%
df.iloc[:2]
# Out:
#   name  age   pet
# 2  Tim   40  bird
# 0  Bob   20   cat

# %%
df.iloc[-1:,]
# Out:
#   name  age  pet
# 1  Jen   30  dog

# %%
#displays everything beyond the 1st column
df.iloc[0:2,1:4]
# Out:
#    age   pet
# 2   40  bird
# 0   20   cat

# %%
df.iloc[1:3,1:5]
# Out:
#    age  pet
# 0   20  cat
# 1   30  dog

# %%
df.iloc[1:3,:]
# Out:
#   name  age  pet
# 0  Bob   20  cat
# 1  Jen   30  dog

# %%
df.iloc[:,2]
# Out:
# 2    bird
# 0     cat
# 1     dog
# Name: pet, dtype: object

# %% [markdown]
# # DISPLAY DATA MIXING INDEX AND COLUMN NAME -NM1N

# %%
df['age'][1]
# Out:
# 0

# %%
df.loc[:,'age']
# Out:
# 2    40
# 0    20
# 1    30
# Name: age, dtype: int64

# %%
df.loc[:,'age':'pet']
# Out:
#    age   pet
# 2   40  bird
# 0   20   cat
# 1   30   dog

# %% [markdown]
# # FILTER FOR DATA

# %%
df.loc[df.age>=30,['name','age']]
# Out:
#   name  age
# 2  Tim   40
# 1  Jen   30

# %%
df
# Out:
#   name  age   pet
# 2  Tim   40  bird
# 0  Bob   20   cat
# 1  Jen   30   dog

# %%
df.loc[df.age<=30,['age','name']]
# Out:
#    age name
# 0   20  Bob
# 1   30  Jen

# %%
df.loc[df.age>=30,'age':'name'] #doesn't work because columns not in order
# Out:
# Empty DataFrame
# Columns: []
# Index: [2, 1]

# %%
df.loc[df.age>=30,['age','name']]
# Out:
#    age name
# 2   40  Tim
# 1   30  Jen

# %%
df.loc[((df.age>=30)&(df.name=='Tim')),['name','age']]
# Out:
#   name  age
# 2  Tim   40

# %%
df.loc[((df.age>30) & (df.name=='Tim')),['name']]
# Out:
#   name
# 2  Tim

# %% [markdown]
# # FILTER FOR BOOLEAN TRUE/FALSE -1Z

# %%
df2 = df[['age','score']]

# %%
(df[df.columns[:]] == 0)
# Out:
#     name    age    pet  score
# 0  False  False  False   True
# 1  False   True  False  False
# 2  False  False  False  False

# %% [markdown]
# # Filter Columns & Display Filtered rows

# %%
df3 = df2.loc[(df2[df2.columns[:]] == 0).any(axis=1)]

# %%
df3
# Out:
#    age  score
# 0   20      0
# 1    0      3

# %%
df4 = df2.loc[~(df2[df2.columns[:]] == 0).any(axis=1)]

# %%
df4
# Out:
#    age  score
# 2   40      4

# %%
df.reset_index()
# Out:
#    index  age name   pet
# 0      2   40  Tim  bird
# 1      0   20  Bob   cat
# 2      1   30  Jen   dog

# %%
df.ix

# %%
df.iloc

# %%
df
# Out:
#   name  age   pet
# 2  Tim   40  bird
# 0  Bob   20   cat
# 1  Jen   30   dog

# %%
df.ix[0];
# Out:
# C:\Users\rjjav\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # DEALING WITH EXCEL FILES

# %%
data = pd.read_csv('test_pandas.csv',header=None) #header=None means the file never had a header to begin with.
data
# Out:
#    0  1     2    3
# 0  0  1   cat  1.1
# 1  1  2   dog  2.2
# 2  2  3  bird  3.3

# %%
testdata = pd.read_csv('test_pandas.csv')
testdata
# Out:
#    0  1   cat  1.1
# 0  1  2   dog  2.2
# 1  2  3  bird  3.3

# %%
#this converts a dataframe into a csv and exports
data.to_csv('test_pandas_no_header.csv', header=False, index=True)

# %%
data = pd.read_csv('test_pandas_no_header.csv', header=None)
data
# Out:
#    0  1  2     3    4
# 0  0  0  1   cat  1.1
# 1  1  1  2   dog  2.2
# 2  2  2  3  bird  3.3

# %%
data2 = pd.read_excel('test_pandas.xlsm','Sheet1')
data2
# Out:
#    Column A Column B  Column C
# 0         1      cat       1.1
# 1         2      dog       2.2
# 2         3     bird       3.3

# %%
data3 = pd.read_excel('test_pandas.xlsm')
data3
# Out:
#    Column A Column B  Column C
# 0         1      cat       1.1
# 1         2      dog       2.2
# 2         3     bird       3.3

# %%
#saving excel sheet with sheets from the previous workbooks
writer = pd.ExcelWriter('test_sheets.xlsx')
data.to_excel(writer,'Original')
data2.to_excel(writer,'Data_Init')
writer.save()

# %% [markdown]
# # DATABASE CONNECTION TO SQL

# %%
#database connection
import sqlite3
conn = sqlite3.connect('test_pandas.db')

# %%
tables = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")

# %%
print(tables)

# %%
for name in tables:
    print(name[0])
# Out:
# test
# new_test
# newtest
# newtest2

# %%
tables

# %%
sql_query = 'SELECT * FROM test'
data = pd.read_sql(sql_query, conn)
data
# Out:
#     id           city    mascot
# 0    1  San Francisco     49ers
# 1    2        Oakland   Raiders
# 2    3        Seattle  Seahawks
# 3    4        Chicago     Bears
# 4    5            NYC      Jets
# 5    6             LA      Rams
# 6    7            ANA  Chargers
# 7    6             LA      Rams
# 8    7            ANA  Chargers
# 9    6             LA      Rams
# 10   7            ANA  Chargers
# 11   6             LA      Rams
# 12   7            ANA  Chargers

# %%
#new data frame with 2 new teams
new_data = pd.DataFrame({'id':[6,7],
                        'city':['LA','ANA'],
                        'mascot':['Rams','Chargers']})
new_data
# Out:
#    id city    mascot
# 0   6   LA      Rams
# 1   7  ANA  Chargers

# %%
#new_data.to_sql('newtest2',conn)

# %%
sql_query = 'SELECT * FROM newtest'
data = pd.read_sql(sql_query,conn)
data
# Out:
#    index city  id    mascot
# 0      0   LA   6      Rams
# 1      1  ANA   7  Chargers

# %%
sql_query = 'SELECT * FROM newtest2'
data2 = pd.read_sql(sql_query,conn)
data2
# Out:
#    index city  id    mascot
# 0      0   LA   6      Rams
# 1      1  ANA   7  Chargers

# %%
new_data.to_sql('test',conn, if_exists = 'append', index = False)

# %%
sql_query = 'SELECT * FROM test'
data = pd.read_sql(sql_query,conn)
data
# Out:
#     id           city    mascot
# 0    1  San Francisco     49ers
# 1    2        Oakland   Raiders
# 2    3        Seattle  Seahawks
# 3    4        Chicago     Bears
# 4    5            NYC      Jets
# 5    6             LA      Rams
# 6    7            ANA  Chargers
# 7    6             LA      Rams
# 8    7            ANA  Chargers
# 9    6             LA      Rams
# 10   7            ANA  Chargers
# 11   6             LA      Rams
# 12   7            ANA  Chargers
# 13   6             LA      Rams
# 14   7            ANA  Chargers

# %%
conn.close()

# %%
import pandas as pd
data = pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(1)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
data.iloc(1)

# %%
data.iloc(0)

# %%
data.iloc[:,3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
#we want to know what's in our data
#data analysis
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
#how many people have null values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#descriptive statistics
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#number of unique
data.Sex.nunique()
# Out:
# 2

# %%
#like group by
data.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#how to analyze categorical variable
data.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#you cannot treat this like categorical variable
data.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# ...

# %%
data.Fare.mean(), data.Fare.median()
# Out:
# (32.2042079685746, 14.4542)

# %%
data.Fare.mode()
# Out:
# 0    8.05
# dtype: float64

# %% [markdown]
# # FILTER 1 COLUMN AND DESCRIBE -AAZ

# %%
#pulling information only for males
data.loc[data.Sex=='male'].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   577.000000  577.000000  577.000000  453.000000  577.000000
# mean    454.147314    0.188908    2.389948   30.726645    0.429809
# std     257.486139    0.391775    0.813580   14.678201    1.061811
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.000000    0.000000    2.000000   21.000000    0.000000
# 50%     464.000000    0.000000    3.000000   29.000000    0.000000
# 75%     680.000000    0.000000    3.000000   39.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  577.000000  577.000000
# mean     0.235702   25.523893
# std      0.612294   43.138263
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   10.500000
# 75%      0.000000   26.550000
# max      5.000000  512.329200

# %%
#pullig information only for males over 18
data.loc[(data.Sex=='male') & (data.Age>18)].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   382.000000  382.000000  382.000000  382.000000  382.000000
# mean    451.502618    0.180628    2.277487   34.480366    0.251309
# std     255.413532    0.385214    0.839614   12.540078    0.511994
# min       1.000000    0.000000    1.000000   19.000000    0.000000
# 25%     223.500000    0.000000    1.250000   25.000000    0.000000
# 50%     459.000000    0.000000    3.000000   31.500000    0.000000
# 75%     671.250000    0.000000    3.000000   42.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  382.000000  382.000000
# mean     0.154450   27.055616
# std      0.541911   48.444562
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   11.000000
# 75%      0.000000   26.550000
# max      5.000000  512.329200

# %% [markdown]
# # FILTERING COLUMNS WITH 1 CONDITION OR 2 -DSGO

# %%
data.loc[data.Sex=='male']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
#pullig information only for males over 18
data.loc[(data.Sex=='male') & (data.Age>18)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 33            34         0       2                 Wheadon, Mr. Edward H
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ...

# %%
data.loc[(data.Sex == 'female') | (data.Age<13)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# ...

# %%
print(data.Sex[data.Sex=='male'].count())
# Out:
# 577

# %%
print(data.Sex[data.Sex=='female'].count())
# Out:
# 314

# %%
zia = data.Sex[data.Sex=='male'].count()
print(zia)
# Out:
# 577

# %% [markdown]
# # GENERAL GROUP BY -91A

# %%
data.groupby('Sex')['Pclass'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Pclass, dtype: int64

# %%
data.groupby('Sex')['Age','Fare'].mean()
# Out:
#               Age       Fare
# Sex
# female  27.915709  44.479818
# male    30.726645  25.523893

# %%
data.groupby(['Sex','Pclass'])['Fare'].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
data.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
test=data.groupby(['Sex','Pclass'])['Survived'].mean()

# %%
print(test)
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
type(test)
# Out:
# pandas.core.series.Series

# %%
test.index
# Out:
# MultiIndex(levels=[['female', 'male'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]],
#            names=['Sex', 'Pclass'])

# %%
test = data.groupby(['Sex','Pclass'])[['Survived']].mean()

# %%
test
# Out:
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %%
new = data.groupby('Sex')[['Survived','Age']].mean()
new
# Out:
#         Survived        Age
# Sex
# female  0.742038  27.915709
# male    0.188908  30.726645

# %%
new
# Out:
#         Survived        Age
# Sex
# female  0.742038  27.915709
# male    0.188908  30.726645

# %%
new.index
# Out:
# Index(['female', 'male'], dtype='object', name='Sex')

# %%
new.reset_index()
# Out:
#       Sex  Survived        Age
# 0  female  0.742038  27.915709
# 1    male  0.188908  30.726645

# %%
new.reset_index(inplace=True)
print(new.index)
new
# Out:
# RangeIndex(start=0, stop=2, step=1)
#       Sex  Survived        Age
# 0  female  0.742038  27.915709
# 1    male  0.188908  30.726645

# %%
#weighted average
import pandas as pd
sales = pd.read_excel('sales-estimate.xlsx')
sales.head(2)
# Out:
#    Account                          Name State           Rep       Manager  \
# 0   714466               Trantow-Barrows    MN  Craig Booker  Debra Henley
# 1   737550  Fritsch, Russel and Anderson    MN  Craig Booker  Debra Henley
#
#    Current_Price  Quantity  New_Product_Price
# 0            500       100                550
# 1            600        90                725

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
# Account              12 non-null int64
# Name                 12 non-null object
# State                12 non-null object
# Rep                  12 non-null object
# Manager              12 non-null object
# Current_Price        12 non-null int64
# Quantity             12 non-null int64
# New_Product_Price    12 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 848.0+ bytes

# %%
sales.describe()
# Out:
#              Account  Current_Price    Quantity  New_Product_Price
# count      12.000000      12.000000   12.000000          12.000000
# mean   436776.500000     405.416667  230.416667         447.083333
# std    262600.384263     123.811777  153.851439         146.480814
# min    141962.000000     225.000000   75.000000         255.000000
# 25%    205025.250000     297.500000  100.000000         337.500000
# 50%    359944.500000     387.500000  175.000000         412.500000
# 75%    718307.750000     512.500000  381.250000         562.500000
# max    740150.000000     600.000000  475.000000         725.000000

# %%
sales['Current_Price'].mean(), sales['New_Product_Price'].mean()
# Out:
# (405.4166666666667, 447.0833333333333)

# %%
sales.head()
# Out:
#    Account                          Name State            Rep       Manager  \
# 0   714466               Trantow-Barrows    MN   Craig Booker  Debra Henley
# 1   737550  Fritsch, Russel and Anderson    MN   Craig Booker  Debra Henley
# 2   146832                  Kiehn-Spinka    TX  Daniel Hilton  Debra Henley
# 3   218895                     Kulas Inc    TX  Daniel Hilton  Debra Henley
# 4   412290                 Jerde-Hilpert    WI     John Smith  Debra Henley
#
#    Current_Price  Quantity  New_Product_Price
# 0            500       100                550
# 1            600        90                725
# 2            225       475                255
# 3            290       375                300
# 4            375       400                400

# %%
#this was from website
sum(sales["Current_Price"] * sales["Quantity"]) / sum(sales["Quantity"])
sum(sales["New_Product_Price"] * sales["Quantity"]) / sum(sales["Quantity"])
# Out:
# 374.63833634719708

# %%
sum(sales.Current_Price * sales.Quantity) / sum(sales['Quantity'])
# Out:
# 342.54068716094031

# %%
#create new column name with math
sales['current_price_times_quantity'] = sales['Current_Price'] * sales['Quantity']
sales
# Out:
#     Account                          Name State            Rep        Manager  \
# 0    714466               Trantow-Barrows    MN   Craig Booker   Debra Henley
# 1    737550  Fritsch, Russel and Anderson    MN   Craig Booker   Debra Henley
# 2    146832                  Kiehn-Spinka    TX  Daniel Hilton   Debra Henley
# 3    218895                     Kulas Inc    TX  Daniel Hilton   Debra Henley
# 4    412290                 Jerde-Hilpert    WI     John Smith   Debra Henley
# 5    740150                    Barton LLC    WI     John Smith   Debra Henley
# 6    141962                    Herman LLC    CA    Cedric Moss  Fred Anderson
# 7    163416                   Purdy-Kunde    CA    Cedric Moss  Fred Anderson
# 8    239344                    Stokes LLC    WA    Cedric Moss  Fred Anderson
# 9    307599   Kassulke, Ondricka and Metz    NV     Wendy Yule  Fred Anderson
# 10   688981                   Keeling LLC    NV     Wendy Yule  Fred Anderson
# ...

# %%
(sales["Current_Price"] * sales["Quantity"]).sum() / sales["Quantity"].sum()
# Out:
# 342.5406871609403

# %%
(sales["New_Product_Price"] * sales["Quantity"]).sum() / sales["Quantity"].sum()
# Out:
# 374.6383363471971

# %%
sales.Manager.nunique()
# Out:
# 2

# %%
sales.Manager.unique()
# Out:
# array(['Debra Henley', 'Fred Anderson'], dtype=object)

# %%
sales.Manager.value_counts()
# Out:
# Fred Anderson    6
# Debra Henley     6
# Name: Manager, dtype: int64

# %%
sales.groupby('Manager')[['Current_Price']].mean()
# Out:
#                Current_Price
# Manager
# Debra Henley      423.333333
# Fred Anderson     387.500000

# %%
sales.groupby('Manager')[['New_Product_Price']].mean()
# Out:
#                New_Product_Price
# Manager
# Debra Henley          471.666667
# Fred Anderson         422.500000

# %%
sales.groupby('Manager')[['New_Product_Price','Current_Price']].mean()
# Out:
#                New_Product_Price  Current_Price
# Manager
# Debra Henley          471.666667     423.333333
# Fred Anderson         422.500000     387.500000

# %% [markdown]
# # MERGING / JOINING DATASETS ON ID -6RNG

# %%
join_data = table1.merge(table2, how='inner', on='id')

# %% [markdown]
# # OVERRIDING INDEX WITH EXISTING COLUMN -0V3R

# %%
df.set_index('column')

# %% [markdown]
# # RESET INDEX

# %%
df.reset_index()

# %% [markdown]
# # LIST CREATION SHORTCUT WITH SPLIT -SP1T

# %%
df = 'NY CA SF MD'.split()

# %%
df
# Out:
# ['NY', 'CA', 'SF', 'MD']

# %% [markdown]
# # FILL NULL NA -808A

# %%
dataset['Title'].fillna(0)

# %% [markdown]
# # Filter column and then show the new count of rows -CNTF1

# %%
sum(df['location']=='MD')

# %%
df[df['location']=='MD']['location'].count()

# %%
df[df['location']=='MD'].count()['location']

# %%
len(df[df['location']=='MD'])

# %%
df['location'].value_counts()

# %% [markdown]
# # Filter then show the new count of rows -CNTF1

# %%
sum((ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95))

# %%
ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)].count()

# %%
len(ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)].index)

# %%
df[df['age']>30]['age'].count()

# %%
sum(df['age']>30)

# %%
len(df[(df['age']>30)].index)

# %% [markdown]
# # GET COLUMN THEN ROW THEN CHARACTER -TH3N

# %%
ecom['CC Exp Date'].iloc[0]
ecom['CC Exp Date'].iloc[0][3:]

# %% [markdown]
# # LAMBDA -'l@mb

# %%
listy = [1,2,3]
list(map(lambda empty: empty*2, listy))
# Out:
# [2, 4, 6]

# %%
list(map(lambda x: x%2==0,listy))
# Out:
# [False, True, False]

# %% [markdown]
# # LIST COMPREHENSION FOR LOOP -LC23

# %%
listy1 = [1,2,3]
empty = [empty*2 for empty in listy1]
empty
# Out:
# [2, 4, 6]

# %%
#regular python equivalent
for empty in listy1:
    print empty*2
# Out:
# 2
# 4
# 6

# %% [markdown]
# # LIST COMPREHENSION IF FOR -LD99

# %%
listy = [1,2,3,4]
[elem for elem in listy if elem == 2]
# Out:
# [2]

# %%
#regular python equivalent
for elem in listy:
    if elem == 2:
        print 2
# Out:
# 2

# %% [markdown]
# # COMPARE 2 DATASETS & SEE WHICH COLUMNS NOT IN -NOT1N

# %%
newdf = df['age'] + df['ageinfuture']

# %% [markdown]
# # Descriptive stat by one column -1127A

# %%
df['age'].describe()
# Out:
# count     3.0
# mean     20.0
# std      20.0
# min       0.0
# 25%      10.0
# 50%      20.0
# 75%      30.0
# max      40.0
# Name: age, dtype: float64

# %% [markdown]
# # PIVOT -P1V

# %%
table = pd.pivot_table(train_df, index =['Pclass'],aggfunc='mean') 
table

# %% [markdown]
# # DROP ROW -DRP3

# %%
df.age.dropna()
df['age'].dropna()

# %% [markdown]
# ## What is the name of highest paid person (including benefits)? -MAX2F

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()]

# %%
#minimum
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].min()]

# %% [markdown]
# ## average (mean) BasePay of all employees per year?

# %%
sal.groupby('Year')['BasePay'].mean()

# %% [markdown]
# # BROADCASTING AND FILLING THE SAME -BR02D

# %%
df['newperson'] = 'hello'

# %% [markdown]
# # Zip 2 lists together into one list of (key,value) tuples

# %%
keys = ['money','cars']
values = [3,2]
zipped = list(zip(keys,values))

# %%
zipped
# Out:
# [('money', 3), ('cars', 2)]
